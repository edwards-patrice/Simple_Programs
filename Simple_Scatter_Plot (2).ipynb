# %% [markdown]
# # Practice File for Patrice

# %% [markdown]
# This is a file that will house practice program for Patrice Edwards.

# %%
#This is a sample plot in python to show a simple scatter plot.

import matplotlib.pyplot as plt

x=[5,4,3,2,1]
y=[5,4,3,2,1]

plt.scatter(x,y, color='red')
plt.title("Y vs. X Data")
plt.ylabel("y-axis")
plt.xlabel("x-axis")

plt.show()
